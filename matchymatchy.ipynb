# %%
import numpy as np
import matplotlib.pyplot as plt

index = np.arange(5)
values = np.array([5, 7, 3, 4, 6]) * 1000
figure = plt.figure(figsize=(8, 5))
axes = figure.add_subplot(1,1,1)
axes.bar(index,values)
axes.set_xticks(index,['apple', 'banana', 'orange', 'tomato', 'guava'])
axes.grid(axis='y')
xmin,xmax,ymin,ymax= axes.axis()
axes.axis([xmin-1, xmax+1, ymin, ymax+1000])

for i in index:
    print(i,values[i],end=' ')
    axes.annotate(str(values[i]),[i-0.2,values[i]+100])
    
    
plt.show()
# Out:
# 0 5000 1 7000 2 3000 3 4000 4 6000

# %%
#ndarray
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
import pandas as pd
series_list = pd.Series(data=[1,2,3,4,5]) #list + 陣列運算
series_list[0], series_list[1], series_list[4]
# Out:
# (1, 2, 5)

# %%
series_dict = pd.Series(data=[1,2,3,4,5],index=['a', 'b', 'c', 'd', 'e']) #dict+ list + 陣列運算
print(series_dict[0], series_dict[1], series_dict[4])
series_dict * 5
# Out:
# 1 2 5
# /tmp/ipykernel_2813/3313479358.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(series_dict[0], series_dict[1], series_dict[4])
# a     5
# b    10
# c    15
# d    20
# e    25
# dtype: int64

# %%
series_dict = pd.Series(data=[89,76,65,92,76],index=['國文', '英文', '數學', '地理', '歷史']) #dict+ list + 陣列運算
series_dict
#series_dict['國文']
# Out:
# 國文    89
# 英文    76
# 數學    65
# 地理    92
# 歷史    76
# dtype: int64

# %%
#Series,values,index
series_dict.values
series_dict.index
series_dict += 3 #陣列運算
series_dict
# Out:
# 國文    131
# 英文    118
# 數學    107
# 地理    134
# 歷史    118
# dtype: int64

# %%
import matplotlib.pyplot as plt
sdata = pd.Series({'Taipei':35000, 'Taoyuan':71000, 'Taichung':16000, 'Kaohsiung':5000})
figure = plt.figure()
axes = figure.add_subplot()
axes.bar(sdata.index, sdata.values)
plt.show()

# %%
sdata
# Out:
# Taipei       35000
# Taoyuan      71000
# Taichung     16000
# Kaohsiung     5000
# dtype: int64

# %%
import pandas as pd

#手動dict建立DataFrame
pd.DataFrame({"徐xx":[67, 92, 82],
              "張xx":[98, 78, 69],
              "王xx":[76, 65, 83]},index=['國文','英文','數學'])
# Out:
#     徐xx  張xx  王xx
# 國文   67   98   76
# 英文   92   78   65
# 數學   82   69   83

# %%
#手動2維list建立DataFrame
pd.DataFrame([{"徐xx":67,'張xx':98,'王xx':76},
              {"徐xx":67,'張xx':98,'王xx':76},
              {"徐xx":67,'張xx':98,'王xx':76}
              ],index=['國文','英文','數學'])
# Out:
#     徐xx  張xx  王xx
# 國文   67   98   76
# 英文   67   98   76
# 數學   67   98   76

# %%
#手動2維list建立DataFrame
pd.DataFrame([[67, 98, 76],
              [92, 78, 65],
              [82, 69, 83]],index=['國文','英文','數學'],columns=['徐xx','張xx','王xx'])
# Out:
#     徐xx  張xx  王xx
# 國文   67   98   76
# 英文   92   78   65
# 數學   82   69   83

# %%
import numpy as np
import pandas as pd

scores = np.random.randint(60,100,size=(50,5))
students = pd.DataFrame(scores,index=range(1,51),columns=["國文","英文","數學","地理","歷史"])
students
# Out:
#     國文  英文  數學  地理  歷史
# 1   60  94  82  85  67
# 2   80  90  60  84  64
# 3   89  93  90  90  77
# 4   66  69  94  63  99
# 5   62  74  70  79  65
# 6   72  80  75  60  71
# 7   81  87  75  60  95
# 8   66  94  67  91  79
# 9   88  99  64  71  71
# 10  68  69  72  97  77
# 11  68  90  72  73  71
# 12  80  81  66  74  74
# 13  99  90  81  77  99
# 14  78  73  66  84  85
# 15  81  76  78  69  62
# 16  61  86  81  82  83
# 17  89  67  95  89  61
# 18  74  63  88  67  90
# 19  84  79  97  78  60
# 20  60  73  70  99  98
# 21  78  95  94  94  67
# 22  93  79  80  65  81
# 23  76  74  82  67  83
# 24  99  76  61  81  91
# 25  60  90  89  66  81
# 26  78  80  76  83  83
# 27  85  88  71  81  89
# 28  64  92  97  83  87
# 29  77  81  86  70  73
# 30  97  77  86  66  88
# 31  97  80  74  99  91
# 32  69  81  74  62  80
# 33  60  69  78  86  62
# 34  76  66  70  66  84
# 35  68  61  65  69  95
# 36  83  91  61  89  86
# 37  77  88  97  84  61
# 38  85  89  64  96  82
# 39  67  73  66  92  83
# ...

# %%
#使用subscript->['字串'],選欄
#使用subscript->[1:5],選列
students['國文']
# Out:
# 1     60
# 2     80
# 3     89
# 4     66
# 5     62
# 6     72
# 7     81
# 8     66
# 9     88
# 10    68
# 11    68
# 12    80
# 13    99
# 14    78
# 15    81
# 16    61
# 17    89
# 18    74
# 19    84
# 20    60
# 21    78
# 22    93
# 23    76
# 24    99
# 25    60
# 26    78
# 27    85
# 28    64
# 29    77
# 30    97
# 31    97
# 32    69
# 33    60
# 34    76
# 35    68
# 36    83
# 37    77
# 38    85
# 39    67
# 40    78
# 41    65
# 42    63
# 43    67
# 44    98
# 45    88
# 46    63
# 47    75
# 48    86
# 49    70
# 50    85
# Name: 國文, dtype: int64

# %%
students[['國文','英文']]
# Out:
#     國文  英文
# 1   60  94
# 2   80  90
# 3   89  93
# 4   66  69
# 5   62  74
# 6   72  80
# 7   81  87
# 8   66  94
# 9   88  99
# 10  68  69
# 11  68  90
# 12  80  81
# 13  99  90
# 14  78  73
# 15  81  76
# 16  61  86
# 17  89  67
# 18  74  63
# 19  84  79
# 20  60  73
# 21  78  95
# 22  93  79
# 23  76  74
# 24  99  76
# 25  60  90
# 26  78  80
# 27  85  88
# 28  64  92
# 29  77  81
# 30  97  77
# 31  97  80
# 32  69  81
# 33  60  69
# 34  76  66
# 35  68  61
# 36  83  91
# 37  77  88
# 38  85  89
# 39  67  73
# 40  78  61
# 41  65  84
# 42  63  66
# 43  67  84
# 44  98  63
# 45  88  77
# 46  63  87
# 47  75  64
# 48  86  78
# 49  70  90
# 50  85  65

# %%
students[0:1]
# Out:
#    國文  英文  數學  地理  歷史
# 1  60  94  82  85  67

# %%
#students.loc[]
#studnets.iloc[]

students.loc[50] , students.iloc[49]
# Out:
# (國文    85
#  英文    65
#  數學    63
#  地理    87
#  歷史    75
#  Name: 50, dtype: int64,
#  國文    85
#  英文    65
#  數學    63
#  地理    87
#  歷史    75
#  Name: 50, dtype: int64)

# %%
#前5位學生
students.loc[1:5], students.iloc[0:5]
# Out:
# (   國文  英文  數學  地理  歷史
#  1  60  94  82  85  67
#  2  80  90  60  84  64
#  3  89  93  90  90  77
#  4  66  69  94  63  99
#  5  62  74  70  79  65,
#     國文  英文  數學  地理  歷史
#  1  60  94  82  85  67
#  2  80  90  60  84  64
